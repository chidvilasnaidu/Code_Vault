# %%
import argparse
parser=argparse.ArgumentParser()
parser.add_argument("--input1")
parser.add_argument("--input2")
arg=parser.parse_args()
val=arg.input1
val2=arg.input2
print(val+val2)
# Out:
# usage: ipykernel_launcher.py [-h] [--input1 INPUT1] [--input2 INPUT2]
# ipykernel_launcher.py: error: unrecognized arguments: -f C:\Users\chidv\AppData\Roaming\jupyter\runtime\kernel-5e26c613-112a-4f8e-b9ce-03a7538b7006.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
