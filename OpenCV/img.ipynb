# %%
import cv2
cv2.__version__
# Out:
# '4.11.0'

# %%
img=cv2.imread(r"C:\Users\chidv\OneDrive\Pictures\Screenshots\Screenshot (48).png")
cv2.imshow('dog', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
