# %% [markdown]
# # Open Ai

# %% [markdown]
# # New Section

# %% [markdown]
# - If there is any private data or keys we use the Secrets in google colab - If there is any private data or keys we use the Secrets in google colab

# %% [markdown]
# Here we Cannot need to remember all the codes rather we can get them directly from git or official documentations

# %%
pip install openai

# %% [markdown]
# Go to below link and create an key :https://platform.openai.com/api-keys?utm_source=chatgpt.com

# %% [markdown]
#  1. Now add the scret keys into Secrets Tab

# %%
Gpt_key  # We cannot directly access the keys for that we import colab.Userdata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3698/320734306.py in <cell line: 0>()
# ----> 1 Gpt_key  # We cannot directly access the keys for that we import colab.Userdata
#
# NameError: name 'Gpt_key' is not defined

# %%
from google.colab import userdata

# %%
api_key1=userdata.get('Gpt_key')
print(api_key1)  # It was printed

# %% [markdown]
# Now Accessing or loading the client sorted into two types:
# 1. Direct access
# 2. Environmental access {preffered}

# %%
from openai import OpenAI

# %%
 # direct access

client= OpenAI( api_key=api_key1 )
client

# %% [markdown]
# - Documentation link : https://github.com/openai/openai-python/blob/main/api.md
# - Compare & Select Models : https://developers.openai.com/api/docs/models/all

# %%
Response= client.chat.completions.create(
    model='gpt-5.4-nano',
    messages=  [
        {"role": "user", "content": "Tell me about yourself ."}
        ]
)
Response

# %% [markdown]
# Above will show error bcoz it only offers Paid services , so Continue With Gemini for free Access , and the process will be the same

# %% [markdown]
# # Gemini

# %%
from google.colab import userdata

# %%
GeminiKey= userdata.get('Gemini_API_Key')
GeminiKey

# %%
# !pip install -q google-genai

# %%
from google import genai

# %%
# 2. Enironment method

import os
os.environ['GEMINI_API_KEY'] = GeminiKey # Gemini

# %%
client = genai.Client()

# %%
response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="Tell me about yourself"
)

# %%
print(response.text)

# %%
from google.colab import userdata

# %%
Gorkkey= userdata.get('Gork_Key')
Gorkkey

# %%
import os
os.environ['GROQ_API_KEY'] = Gorkkey

# %%
pip install groq

# %%
from groq import Groq

# %%
client = Groq()

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "which Model is best Groq or ChatGPT",
        }
    ],
    model="llama-3.3-70b-versatile",
)

# %%
chat_completion

# %%
chat_completion.choices[0].message.content

# %% [markdown]
# ## Q/A Project Using Groq AI

# %%
from google.colab import userdata

# %%
Keys= userdata.get('Gork_Key')
Keys

# %%
import os
os.environ['GROQ_API_KEY']=Keys

# %%
pip install groq

# %%
from groq import Groq

# %%
client = Groq()

# %%
UserInput=input("Enter Your Question : ")
systemprompt="hey Bot Make sure to give in simple and understandale format , Not extending 150 words , use lists if only required "


chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": UserInput
        },
          {
            "role": "system",
            "content": systemprompt # systemprompt used so say instructions to AI mo
        }
    ],
    model="llama-3.3-70b-versatile",
)

# %%
chat_completion.choices[0].message.content

# %%
UserInput=input("Enter Your Question : ")
systemprompt="hey Bot Make sure to give in simple and understandale format , Not extending 150 words , use lists if only required "

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": UserInput
        },
          {
            "role": "system",
            "content": systemprompt
        }
    ],
    model="llama-3.3-70b-versatile",
)

# %%
chat_completion

# %%
while True:
  UserInput=input("Enter Your Question : ")
  systemprompt="hey Bot Make sure to give in simple and understandale format , Not extending 150 to 250words , use lists if only required "

  if UserInput.lower() in ['over','bye', 'thank you','okay','quit','quit()']:
    print("Thank you!, Have a Great Day")
    break
  else:
    chat_completion = client.chat.completions.create(
      messages=[
          {
              "role": "user",
              "content": UserInput
          },
            {
              "role": "system",
              "content": systemprompt
          }
      ],
      model="llama-3.3-70b-versatile",
      )
    print(chat_completion.choices[0].message.content)

# %% [markdown]
# Practice

# %%
from openai import OpenAI

# %%
# Accessing the keys

from google.colab import userdata

# %%
Gpt_key= userdata.get('Gpt_key')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1037/2890233189.py in <cell line: 0>()
# ----> 1 Gpt_key= userdata.get('Gpt_key')
#
# NameError: name 'userdata' is not defined

# %%
#

# %% [markdown]
# Environment variables

# %%
import os

# %%
os.environ["OPENAI_API_KEY"] = Gpt_key

# %%
client=OpenAI()

# %%
Response= client.chat.completions.create(
    model='gpt-5.4-nano',
    messages=  [
        {"role": "user", "content": "Tell me about yourself ."}
        ]
)
Response
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipykernel_5506/2714228871.py in <cell line: 0>()
# ----> 1 Response= client.chat.completions.create(
#       2     model='gpt-5.4-nano',
#       3     messages=  [
#       4         {"role": "user", "content": "Tell me about yourself ."}
#       5         ]
#
# /usr/local/lib/python3.12/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     296                         msg = f"Missing required argument: {quote(missing[0])}"
#     297                 raise TypeError(msg)
# --> 298             return func(*args, **kwargs)
#     299
#     300         return wrapper  # type: ignore
#
# ...

# %%
# Gemini`m

# %% [markdown]
# Gemini

# %%
from google.colab import userdata

# %%
gemini=userdata.get('YT_PDF')

# %%
from google import genai

# %%
import os
os.environ['GEMINI_API_KEY']=gemini

# %%
client=genai.Client()

# %%
response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents="Explain how transformers works in a few words",
)

print(response.text)
# Out:
# Transformers process entire texts simultaneously, using an **"attention" mechanism** to calculate how every word relates to every other word in context.

# %% [markdown]
# Gork - By using gork we can give context or promt to the model

# %%
pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 3.6 MB/s eta 0:00:00
# ...

# %%
from groq import Groq

# %%
from google.colab import userdata

# %%
Key_G=userdata.get('Gork_Key')
Key_G
# Out:
# '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'

# %%
import os
os.environ['GROQ_API_KEY']=Key_G

# %%
client=Groq()

# %%
chat_completion1 = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of fast language models",
        }
    ],
    model="llama-3.3-70b-versatile",
)

# %%
print(chat_completion1.choices[0].message.content)
# Out:
# Fast language models are crucial in today's world, and their importance can be understood from several perspectives:
#
# 1. **Efficient Processing**: Fast language models can process and analyze vast amounts of text data quickly, which is essential for many applications such as text classification, sentiment analysis, and language translation. This efficiency enables businesses and organizations to make data-driven decisions in real-time.
# 2. **Improved User Experience**: Fast language models enable faster response times in applications like chatbots, virtual assistants, and language translation software. This leads to a better user experience, as users can quickly receive answers to their queries or complete tasks without waiting for a long time.
# 3. **Real-time Applications**: Fast language models are necessary for real-time applications such as:
# 	* Live language translation: enabling people to communicate across language barriers in real-time.
# ...

# %% [markdown]
# Giving the Prompt to system

# %%
chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of fast language models",
        },
        {
            "role": "system",
            "content": "Give the Output in 2 Bullet Points",
        }
    ],
    model="llama-3.3-70b-versatile",
)

# %%
print(chat_completion.choices[0].message.content)
# Out:
# * **Improved Efficiency and Productivity**: Fast language models are essential for enhancing the efficiency and productivity of various natural language processing (NLP) tasks, such as language translation, text summarization, and sentiment analysis. They enable rapid processing and generation of human-like text, which is critical for applications like chatbots, virtual assistants, and content generation.
# * **Enhanced User Experience and Applications**: The importance of fast language models also lies in their ability to provide an enhanced user experience in real-time applications, such as voice assistants, language translation apps, and automated customer support systems. By generating human-like responses quickly, these models can facilitate more natural and intuitive interactions between humans and machines, opening up new possibilities for NLP applications in industries like healthcare, education, and entertainment.

# %% [markdown]
# # Small Q/A with Groq

# %%
from google.colab import userdata
from groq import Groq
import os
key=userdata.get('Gork_Key')
os.environ['GROQ_API_KEY']=key
client=Groq()
#-----------------------------------------------------------------------------
#-----------------------------------------------------------------------------
def invoke_Gork(client, input):
    chat_completion = client.chat.completions.create(
      messages=[
          {
              "role": "user",
              "content": f"{input}",
          }
      ],
      model="llama-3.3-70b-versatile",)
    return chat_completion.choices[0].message.content

#-----------------------------------------------------------------------------
#-----------------------------------------------------------------------------
def invoke_Gork_with_prompt(client,input,prompt):

      chat_completion = client.chat.completions.create(
      messages=[
          {
              "role": "user",
              "content": f"{input}",
          },
          {
              "role": "system",
              "content": f"{prompt}",
          }
      ],
      model="llama-3.3-70b-versatile",)
      return chat_completion.choices[0].message.content



#-----------------------------------------------------------------------------
#-----------------------------------------------------------------------------

qsn=input(" Enter Question: ")
if qsn !="":
  prmpt=input(" Any Prompt Suggestions ...[Yes/No] : ")
  if prmpt.casefold()=='yes':
    prompt=input("Enter Suggestions...: ")
    print(" ")
    print(invoke_Gork_with_prompt(client, qsn,prompt))
  elif prmpt.casefold()=='no':
    print(" ")
    print(invoke_Gork(client, qsn))
  else:
    print(" Please Enter Correct input...! ")
else:
  print(" Please Enter Valid question : ")
# Out:
#  Enter Question: what is overfitting in ML
#  Any Prompt Suggestions ...[Yes/No] : yes
# Enter Suggestions...: give it very short and 4 bullet points
#
# Overfitting in ML refers to a model that is too complex, performing well on training data but poorly on new data. Key points:
# * Model is too complex
# * Performs well on training data
# * Fails to generalize to new data
# * Leads to poor predictive performance
