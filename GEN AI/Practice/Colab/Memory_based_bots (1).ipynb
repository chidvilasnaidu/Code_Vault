# %% [markdown]
# We are using GenAI [ GEMINI] for this

# %%
from google.colab import userdata

# %%
Genkey=userdata.get('Gemini_API_Key')
Genkey
# Out:
# 'AIzaSyAr7fCRwveNlh7nFco6oxVI_GtiTVesVbk'

# %%
from google import genai
import os

# %%
os.environ['GEMINI_API_KEY']=Genkey

# %%
client = genai.Client()

# %%
response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents="Explain how AI works in a few words",
)

# %%
response.text
# Out:
# '**AI analyzes vast data, finds patterns, and makes decisions.**'

# %% [markdown]
# # Multi-turn conversations

# %%
chat = client.chats.create(model="gemini-3.5-flash")

# %%
chat.send_message('hello')
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text='Hello! How can I help you today?',
#             thought_signature=b'\x12\xb9\x05\n\xb6\x05\x01\x0c9\xd6\xc7\xa1\x10\x07^\x9a\xa0u\xa6v\xf3\x90B\x936|"E\x95\xcf9\x99B\x1af4x\xa9\x15T\x87\xd9\xa2\xed\'\xfe\x92\xb7c\xbf\xec\xb6\x191~\x0e\xc9C\xe7\xa1\xfc\xaf\xb2|U\xeb\xb2\xfd\xc6\x10\x03\xf7\xbf\x83N\xaa\x94h\xce=Ut\x14\xdd\xcdm4,\xccX\xb4B\xd3Zl\x84u...'
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-3.5-flash',
#   response_id='6LARavmWGYiwqtsP5sONqQk',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=9,
#     prompt_token_count=2,
#     prompt_tokens_details=[
# ...

# %%
res=chat.send_message('My name is chidvilas what is Your name ')
res.text
# Out:
# 'Hello Chidvilas! Nice to meet you. \n\nMy name is Gemini. I am a large language model built by Google. How can I help you today?'

# %%
res=chat.send_message('what is ml ')
res.text
# Out:
# '**ML** stands for **Machine Learning**. \n\nIt is a branch of **Artificial Intelligence (AI)** that focuses on building systems that can learn from data, identify patterns, and make decisions with minimal human intervention.\n\nHere is an easy way to understand it:\n\n### The Difference: Traditional Programming vs. Machine Learning\n\n* **Traditional Programming:** You write the rules. \n  * *Example:* You write code telling the computer: *"If an email contains the word \'free money\', move it to the spam folder."*\n* **Machine Learning:** The computer figures out the rules by itself.\n  * *Example:* You feed the computer thousands of emails labeled "spam" and "not spam." The computer looks at them, finds patterns on its own, and learns how to identify spam in the future.\n\n---\n\n### Real-World Examples of ML\nYou probably use Machine Learning every day without realizing it:\n1. **Recommendations:** When Netflix suggests a movie or Spotify recommends a song, they use ML to analyze
# ...

# %%
res=chat.send_message('what is my name ')
res.text
# Out:
# 'Your name is **Chidvilas**! 😊'

# %%
res=chat.send_message('what is my first question ')
res.text
# Out:
# 'Your first question was: **"what is Your name"** (which you asked right after introducing yourself)!'

# %%
chat.get_history()
# Out:
# [UserContent(
#    parts=[
#      Part(
#        text='hello'
#      ),
#    ],
#    role='user'
#  ),
#  Content(
#    parts=[
#      Part(
#        text='Hello! How can I help you today?',
#        thought_signature=b'\x12\xb9\x05\n\xb6\x05\x01\x0c9\xd6\xc7\xa1\x10\x07^\x9a\xa0u\xa6v\xf3\x90B\x936|"E\x95\xcf9\x99B\x1af4x\xa9\x15T\x87\xd9\xa2\xed\'\xfe\x92\xb7c\xbf\xec\xb6\x191~\x0e\xc9C\xe7\xa1\xfc\xaf\xb2|U\xeb\xb2\xfd\xc6\x10\x03\xf7\xbf\x83N\xaa\x94h\xce=Ut\x14\xdd\xcdm4,\xccX\xb4B\xd3Zl\x84u...'
#      ),
#    ],
#    role='model'
#  ),
#  UserContent(
#    parts=[
#      Part(
#        text='My name is chidvilas what is Your name '
#      ),
#    ],
#    role='user'
#  ),
#  Content(
#    parts=[
#      Part(
#        text="""Hello Chidvilas! Nice to meet you.
#
#  My name is Gemini. I am a large language model built by Google. How can I help you today?""",
# ...
