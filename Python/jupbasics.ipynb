# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# hello world

# %% [markdown]
# # this is main heading

# %% [markdown]
# ## Sub heading

# %% [markdown]
#   shift + enter --- run
#   esc+ m = code to markup
#   esc+y  = markup to code
#
#  Esc+ A creates a cell above selected
#  Esc + B creates a cell below selected
#
#
#  " #  - main  hedding      ## second main heading
#     ### sub heading
#     **  ** bold
#     ```` highlighing
#     * * italics
#     *  for bullet
#     - for bullet
#     d+d for deleting cell

# %% [markdown]
# # Chidvilas Kumkapalla
#
#
# ## About Me
# I am *Chidvilas Kumkapalla*, an **Information Technology** graduate from ` NIT Jalandhar`. I have hands-on experience in full-stack development, cloud computing, and CRM tools. I’ve built impactful projects like FarmSense360, Medha AI Chatbot, and a Diabetes Prediction System using Python, React.js, and RESTful APIs. I completed a cloud internship at 1Stop, gaining experience with AWS and Azure. I’m a quick learner, problem-solver, and team player with a strong interest in building tech-driven solutions.
#
# ---
#
# ## Key Details
# - **Email:** kumkapallachidvilas2003@gmail.com
# - **Phone:** +91 9666331979
# - **Location:** Gudivada, Andhra Pradesh
# - **Languages:** Telugu, English, Hindi
# - **Availability:** Immediate
# - **Willing to Relocate:** Yes

# %%
sal=100000
rem=sal-40000
print(rem)
# Out:
# 60000

# %%
import random

# %%
sal=random.randint(100000,500000)
exp=random.randint(40000,80000)
rem=sal-exp
print(rem)
# Out:
# 366376

# %%
val1= str


if(type(val1)==int):
    val1=val1+5
    print(val1)
else:
    print("this is not a int")
# Out:
# this is not a int

# %%
#operators
a=1
b=1
print(a==b)   # == is comparing varible sby value returing true
# Out:
# True

# %%
#identity  operators 
# using is 

a=2
b=2 
print(a is b)  ## returns true for int Only possible in (int) case
# Out:
# True

# %%
f1=8.0
f2=8.0
a=[2,5,15]
b=[2,5,15]


print(f1==f2) #True
print(a==b)   #True

print(f1 is f2) #false
print(a is b)   #false
# Out:
# True
# True
# False
# False

# %%
10&5
# Out:
# 0

# %%
print(10>>2)
# Out:
# 2

# %%
print(~(5))   #  -[x+1]  =-[5+1]= 6
# Out:
# -6

# %%
a=12
b=float(a)
print(b)
# Out:
# 12.0

# %%
users
# Out:
# ['user1', 'user2', 'user3', 'user4', 'user5']

# %%
database = []
# database = [[[name,user_1],[age,number],[password,xxx]],[[name,user_2],[age,number],[password,xxx]]]
sb1=[]
for outer in range(2):
    for inner in range(3):
        name=(input(" user name"))
        sb1.append(name)
        age=int(input(" age: "))
        sb1.append(name)
        passs=(input(" pass"))
        sb1.append(name)
print(sb1)
# Out:
#  user name bjhi
#  age:  35
#  pass kl
#  user name bji
#  age:  65
#  pass skj
#  user name dkj
#  age:  35
#  pass kdj
