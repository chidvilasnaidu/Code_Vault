# %%
# 1. Strings are Immutable

str='hello'
str.capitalize()
# Out:
# 'Hello'

# %%
print(str)
# Out:
# hello

# %%
#if you store new value into varible either with same name of diffrente it will shows mutable  the behaviour 
str='hello'
str=str.capitalize()
#orr
str2=str.capitalize()

# %%
print(str)
# Out:
# Hello

# %%
print(str2)
# Out:
# Hello

# %%
#len used to return the length of string 
str='hello'
print(len(str))
# Out:
# 5

# %%
# String Concatenation Use + to join strings.

first = "Good"
second = "Morning"
print(first +  second) ## GoodMorning
print(first + " " + second)  # Good Morning
# Out:
# GoodMorning
# Good Morning

# %%
#String Repetition Use * to repeat strings.
print("Hi! " * 3)  # Hi! Hi! Hi!
# Out:
# Hi! Hi! Hi!

# %%
dir(str)
#it is used to print methods on strings
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
help(str.casefold) #used to find find how the method works



#
# Out:
# Help on method_descriptor:
#
# casefold(self, /) unbound builtins.str method
#     Return a version of the string suitable for caseless comparisons.

# %%
s1='chidvilas'
s1.capitalize()
# Out:
# 'Chidvilas'

# %%
# strip()
#removes the spaces in string=
str=" hello world "  #striping whitespaces at starting and ending
str.strip()
# Out:
# 'hello world'

# %%
str2="-- hesllo world --"
str2.strip('-')
# Out:
# ' hesllo world '

# %%
help(str.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
s1.upper()
# Out:
# 'CHIDVILAS'

# %%
s1.lower()
# Out:
# 'chidvilas'

# %%
s1.count('i')
# Out:
# 2

# %%
s2='ChiDVilAs'
print(s2.casefold())
# Out:
# chidvilas

# %%
s2.startswith('C')
# Out:
# True

# %%
s=" this is the line "
s.split() #here  it will split the sentence by space by default 
#space is a delemeter
# Out:
# ['this', 'is', 'the', 'line']

# %%
date="12-06-2025"
date.split("-")
# Out:
# ['12', '06', '2025']

# %%
email="chidvilasnaidu99@gmail.com"
email.split("@")
# Out:
# ['chidvilasnaidu99', 'gmail.com']

# %%
v1='chiddu'
v2=59
v3='98'
v1.isnumeric()
#v2.isnumeric()   #-- returns error message
# Out:
# True

# %%
help(str.isnumeric)
# Out:
# Help on method_descriptor:
#
# isnumeric(self, /) unbound builtins.str method
#     Return True if the string is a numeric string, False otherwise.
#
#     A string is numeric if all characters in the string are numeric and there is at
#     least one character in the string.

# %%
v1.isnumeric()
# Out:
# False

# %%
v3.isnumeric()
# Out:
# True

# %%
s1='chidvilas'
s1.split()
# Out:
# ['chidvilas']

# %%
help(str.find)
# Out:
# Help on method_descriptor:
#
# find(...) unbound builtins.str method
#     S.find(sub[, start[, end]]) -> int
#
#     Return the lowest index in S where substring sub is found,
#     such that sub is contained within S[start:end].  Optional
#     arguments start and end are interpreted as in slice notation.
#
#     Return -1 on failure.

# %%
#find method is used to search given element in string and return index
s1='chidvilas'
s1.find("s")
# Out:
# 8

# %%
help(str.index)
# Out:
# Help on method_descriptor:
#
# index(...) unbound builtins.str method
#     S.index(sub[, start[, end]]) -> int
#
#     Return the lowest index in S where substring sub is found,
#     such that sub is contained within S[start:end].  Optional
#     arguments start and end are interpreted as in slice notation.
#
#     Raises ValueError when the substring is not found.

# %%
s1='chidvilas'
s1.index("i")
# Out:
# 2

# %%
diffrience="find and index"
diffrience.find("z")
# Out:
# -1

# %%
diffrience.index("z")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 diffrience.index("z")
#
# ValueError: substring not found

# %%
str="chidvilas naidu kumkapalla"
print(str[0:9])
# Out:
# chidvilas

# %%
str[:10]
# Out:
# 'chidvilas '

# %%
str[10:]
# Out:
# 'naidu kumkapalla'

# %%
str[9]
# Out:
# ' '

# %%
str[:]
# Out:
# 'chidvilas naidu kumkapalla'

# %%
str[::]
# Out:
# 'chidvilas naidu kumkapalla'

# %%
str[::1]
# Out:
# 'chidvilas naidu kumkapalla'

# %%
str[0:9:2]  #skip value is 2
# Out:
# 'civls'

# %%
str[::-1]
# Out:
# 'allapakmuk udian salivdihc'

# %%
s2= 'hello world'

# %%
s2[-5:]
# Out:
# 'world'

# %%
s2[-5::2]
# Out:
# 'wrd'

# %%
st='chidvilas skajlskcnKL'
lst=[]
for every in st:
    if every not in lst:
        lst.append(every)
    else:
        pass
dict1={i:st.count(i) for i in lst}

# %%
t1=(1,4,5)
t2=(5,6,7)
t1+t2
t1
# Out:
# (1, 4, 5)

# %%
d={'a':125,'b':57,'d':95}
lst=d.values()
if(lst[0]>lst[2
print(ans)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 3
#       1 d={'a':125,'b':57,'d':95}
#       2 lst=d.values()
# ----> 3 print(ans)
#
# NameError: name 'ans' is not defined

# %%
import random
lst=random.sample(range(5,50),15)
lst
# Out:
# [20, 14, 29, 42, 18, 16, 32, 27, 7, 22, 38, 21, 43, 30, 24]

# %%
mini=lst[0]
for i in range(len(lst)):
    if(lst[i]<mini):
        mini=lst[i]
    else:
        pass

# %%
lst.sort(reverse=True)

# %%
lst
# Out:
# [43, 42, 38, 32, 30, 29, 27, 24, 22, 21, 20, 18, 16, 14, 7]

# %%
t=(5,1,2,3,5,6)

# %%
t[3:]
# Out:
# (3, 5, 6)

# %%
st='chidvilas skajlskcnKL'
st.replace('skajlskcnKL','Naidu')
# Out:
# 'chidvilas Naidu'

# %%
st.index('a')
# Out:
# 7

# %%
def fibo(n):
        if n==0:
            return 0
        elif n==1:
            return 1
        else:
            return fibo(n-1)+fibo(n-2)
    for i in range(num):
        fibo(i)
nterms(10)

# %%
def fibo(n):
    if n==0:
        return 0
    elif n==1:
        return 1
    else:
        return fibo(n-1)+fibo(n-2)

# %%
{i:i**2 for i in range(1,5)}
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16}

# %%
sen="hello i qam sa sentence bmdwnlkkkkk"
lst=sen.split()
lar=''
for every in lst:
    if(len(every)>len(lar)):
        lar=every
    else:
        pass
print(lar)
# Out:
# bmdwnlkkkkk
