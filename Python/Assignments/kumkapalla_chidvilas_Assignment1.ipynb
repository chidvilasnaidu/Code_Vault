# %% [markdown]
# # Kumkapalla chidvilas Assignment1 in LMS
# #### 50 Questions

# %%
#1 John has 6 apples and 7 bananas. How many fruits does John have?

def john(apples, bananas):
    return(apples+bananas)
print("total number of fruits john have ",john(6,7))
# Out:
# total number of fruits john have  13

# %%
#2. Emma read 15 pages yesterday and 10 pages today. Did she read more than 20 pages in total?
def Emma(yp,tp):
    if(yp+tp>20):
        print(" yes, emma read more than 20 pages")
    else:
        print("nope")
Emma(15,10)
# Out:
#  yes, emma read more than 20 pages

# %%
#3. A bag contains 12 red balls and 8 blue balls. Is the number of red balls greater than blue balls?

red=12
blue=8
if(red>blue):
    print("yes red is greater than blue")
else:
    print("red is less than blue")
# Out:
# yes red is greater than blue

# %%
#4 Mike had 30 candies and gave 12 to his friend. How many does he have now?
mike=30
print("mike has ",mike-12,"candies")
# Out:
# mike has  18 candies

# %%
# 5. Sarah bought 5 pens at $3 each. How much did she spend?
pens=5
print(f" sarah spent {pens*3}$ ")
# Out:
#  sarah spent 15$

# %%
#6. There are 45 cookies equally divided among 5 kids. How many does each get?
cookies=45
print(f"Each children can get {cookies//5} cookies")
# Out:
# Each children can get 9 cookies

# %%
#7. Tom scored 89 in math and 76 in science. Did he score more than 160 in total?
math=89
scienc=76
if(math+scienc>160):
    print(" tom scores greater than 160")
else:
    print("nope")
# Out:
#  tom scores greater than 160

# %%
#8. A store sells apples at $2.50 each. If you buy 4, is the total cost more than $10?
apple=2.50
if(apple*4>10):
    print(" yes If you buy 4, is the total cost more than $10")
else:
    print("nope")
# Out:
# nope

# %%
#9. Alice has $100 and buys 3 books for $25 each. Will she have any money left?
money=100
book=25
if(money-book*3!=0):
    print(" Alice have money left")
else:
    print("nope")
# Out:
#  Alice have money left

# %%
#10. A rectangle has length 10 and width 4. Is its area greater than its perimeter?
L=10
W=4
print("area is",L*W)
# Out:
# area is 40

# %%
#11. Two friends have 45 and 55 marbles respectively. Do they have equal number of marbles?
f1=45
f2=55
if( f1==f2):
    print(" yes equal no of apples")
else:
    print("nope")
# Out:
# nope

# %%
#12. A car travels 60 km in 1 hour and a bike 40 km in the same time. Is the car faster?
car=60
bike=40

if(car>bike):
    print("car is faster")
else:
    print("bike is faster")
# Out:
# car is faster

# %%
#13. A chocolate costs $2. You have $9. Can you buy 5 chocolates?
c=2
t=19
if( t%2==5 ):
    print(" yes ,we can by 5 chocolates")
else:
    print("nope")
# Out:
# nope

# %%
#14. A container holds 100 liters of water. If 30 liters are used, is more than half remaining?

tc=100
half=tc/2
if( tc-30>half ):
    print(" yes,more than half remaining")
else:
    print("nope")
# Out:
#  yes,more than half remaining

# %%
#15. Two numbers are 13 and 17. Is their sum an even number?
t1=13
t2=17
sum=13+17
if(sum%2==0):
        print(" yes prime number")
else:
    print("nope")
# Out:
#  yes prime number

# %%
#16. Peter has 5 books, each weighing 1.2 kg. Is the total weight more than 6 kg?
weigt=1.2
if(weigt*5>5):
    print(" nope not more than 6kg")
else:
    print("yes")
# Out:
#  nop not more than 6kg

# %%
#17. A triangle has sides 3, 4, and 5. Is it a right-angled triangle?
l=3*3
b=4*4
h=5*5
if(l+b<=h):
    print(" yes it is right angled triangle")
elif(b+h<=l):
    print(" yes it is right angled triangle")
elif(h+l<=b):
    print(" yes it is right angled triangle")
else:
    print("Nope")
# Out:
#  yes it is right angled triangle

# %%
#18. Jenny had $50, bought items worth $35. Does she have less than $20 left?

total=50
if(total-35<20):
    print(" yes,she have less than $20 left")
else:
    print("nope, more than 20 left")
# Out:
#  yes,she have less than $20 left

# %%
#19. A worker earns $80 per day. Is earning from 6 days more than $500?
pay=80
if(pay*6>500):
    print(" yes,he earning from 6 days more than $500")
else:
    print("nope")
# Out:
# nope

# %%
#20. A movie ticket costs $12. Can you buy 4 with $50?
price=12
if(price*4<=50):
    print(" yes we can buy ")
else:
    print("nope")
# Out:
#  yes we can buy

# %%
#21. If a bottle contains 750ml, do 4 bottles hold more than 3 liters?
bottle=750
cap4=4*bottle
if( cap4>3000   ):
    print(" yes,it can hold more than 3 ")
else:
    print("nope")
# Out:
# nope

# %%
#22. Is the difference between 100 and 37 greater than 60?

if( 100-37>60   ):
    print(" yes ")
else:
    print("nope")
# Out:
#  yes

# %%
#23. Does dividing 81 by 9 result in a number greater than 8?

if(  81/9>8  ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#24. Are 5 multiplied by 6 and 30 equal?

if( 6*5==30   ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#25. Do two squares of side 4 and 5 have the same area?
s1=4*4
s2=5*5
if( s1==s2 ):
    print(" yes, same area ")
else:
    print("nope,not same")
# Out:
# nope,not same

# %%
#26. A basket holds 18 apples. If you eat 6, do you have fewer than 15 left?
total=18
eat=6
if( 18-6<15   ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#27. Sam travels 120 km in 2 hours. Is his speed 60 km/hr?


if(120/2==60   ):
    print(" yes, his speed 60 km/hr ")
else:
    print("nope")
# Out:
#  yes, his speed 60 km/hr

# %%
#28. Is 7 + 3 * 2 equal to 20?
eq=7 + 3 * 2
if(eq==20):
    print(" yes, ")
else:
    print("nope")
# Out:
# nope

# %%
#29. Jane bought 2 pens and 3 pencils. If a pen is $2 and pencil $1, did she spend $9?


if(2*2+3*1==9):
    print(" yes, ")
else:
    print("nope")
# Out:
# nope

# %%
#30. You have 3 boxes, each holding 12 balls. Are total balls more than 35?

if( 3*12>35   ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#31. A triangle has angles 60, 60, and 60. Do they sum to 180?

if( 60+60+60==180  ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#32. If you split 100 into two equal parts, is one part greater than 60?
s=100/2
if(s>60    ):
    print(" yes, ")
else:
    print("nope")
# Out:
# nope

# %%
#33. Mike earned $400 in 8 days. Did he earn $50 daily?

if( 400/8>=50   ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#34. Does subtracting 20 from 50 give 30?

if(  50-20==30):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#35. Are 10 + 15 and 5 * 5 equal?

if( 10+15==5*5   ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#36. If a packet has 48 candies, can 6 kids get more than 7 each?

if( 48/6>=7   ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#37. Compare 5 ** 2 and 25. Are they the same?

if( 5**2==25   ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#38. Is (10 + 2) * 3 greater than 35?

if( (10 + 2) * 3>35  ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#39. Do 8 and 8.0 compare equal?

if(  8==8.0  ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#40. A rope is cut into 3 pieces of 10, 15, and 25 meters. Is the total 50?

if(10+15+25==50    ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#41. Multiply 4 by 4. Is the result less than 20?

if(  4*4<20  ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#42. Add 13 and 7. Is the result divisible by 5?
r=(13+7)%5
if( r==0 or r==5  ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#43. 20 apples are equally shared between 5 students. Does each get 4?

if( 20/5>=4  ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#44. Subtract 15 from 60. Is the result equal to 45?

if( 60-15==45   ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#45. Compare 3 * 3 + 1 and 10. Are they equal?
if(  3*3+1==10  ):
    print(" yes, they are equal ")
else:
    print("nope")
# Out:
#  yes,

# %%
#46. If you double 12, is the result more than 25?
if( 12+12>=25   ):
    print(" yes, ")
else:
    print("nope")
# Out:
# nope

# %%
#47. Are 100 divided by 4 and 25 equal?
if( 100/4==25   ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#48. Is (9 - 3) * 2 greater than 10?
g=(9 - 3) * 2
if(  g>10  ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
#49. If you have $99 and spend $33 three times, will anything be left?
t=99
s=33*3

if( t-s>0   ):
    print(" yes, ")
else:
    print("nope")
# Out:
# nope

# %%
#50. Add 5.5 and 4.5. Is the result 10?
if(   5.5+4.5==10 ):
    print(" yes, ")
else:
    print("nope")
# Out:
#  yes,

# %%
n=2016

if(n%4==0):
    if(n%100!=0 or n%400==0):
        print("Leap year")
    else:
        print("non Leap year")
else:
    print('non leap year')
# Out:
# Leap year
