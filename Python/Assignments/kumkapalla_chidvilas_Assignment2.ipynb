# %%
#Question 1
name= input("Enter Your name ")
print(name)
# Out:
# Enter Your name  kumkapalla chidvilas
# kumkapalla chidvilas

# %%
#question2
import random as rd
lnum=rd.randint(1,10)
dnum=lnum*2
res=dnum//2
fres=res-lnum
print(fres)
# Out:
# 3
# 0

# %%
#Question 3
age=int(input("Enter the age: "))
print("In five years your age will be :", age+5)
# Out:
# Enter the age:  15
#  In five years your age will be : 20
