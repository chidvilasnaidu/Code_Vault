# %%
import requests
import pandas as pd
def main():
    factin=int(input("How many facts you want to create : "))
    users=int(input("How many Random user details you want to create : "))
    with open('C:\Users\chidv\OneDrive\Desktop\Funtions\fun.py','w') as file:
        file.writ
    #print(getcatfacts(factin))

   # print(" random users table is :")
    #print(getrandom_users(users))

    
def getcatfacts(n):  # Helper Funtion1
     dict2={}
     dicat={'id':[],'facts':[]}
     for i in range(1,n):
          fact=requests.get('https://catfact.ninja/fact')
          dict2[f'fact{i}']=fact.json()['fact']
     for every in dict2:
           dicat['id'].append(every)
           dicat['facts'].append(dict2[every])
     f=pd.DataFrame(dicat)
     return(f)


def getrandom_users(n): #hepler funtion2
    
    dict1={'name':[],'city':[],'location':[],'state':[],'email':[],'phn_num':[]}
    for i in range(1,n+1):
        randusr=requests.get('https://randomuser.me/api/')
        randusr=randusr.json()
        f=randusr['results'][0]['name']['first']
        l=randusr['results'][0]['name']['last']
        data={
            'name':f+' '+l,
            'city':randusr['results'][0]['location']['city'],
            'location':randusr['results'][0]['location'],
            'state':randusr['results'][0]['location']['state'],
            'email':randusr['results'][0]['email'],
            'phn_num':randusr['results'][0]['phone']
        }
        for every in dict1:
            dict1[every].append(data[every])
    df=pd.DataFrame(dict1)
    return(df)

main()
# Out:
# How many facts you want to create :  5
# How many Random user details you want to create :  5
#       id  \
# 0  fact1
# 1  fact2
# 2  fact3
# 3  fact4
#
#                                                                                                                                            facts
# 0                                                                 The first official cat show in the UK was organised at Crystal Palace in 1871.
# 1  Contrary to popular belief, the cat is a social animal. A pet cat will respond and answer to speech , and seems to enjoy human companionship.
# 2                                                                                The Pilgrims were the first to introduce cats to North America.
# 3                                                                                   It is estimated that cats can make over 60 different sounds.
#  random users table is :
#                   name                 city  \
# 0         Joann Romero         Newport News
# 1      Elouan Gaillard        Saint-Étienne
# 2  Marisela Villagómez           La Ventosa
# 3       Agnes Teixeira  Teixeira de Freitas
# 4     Blanca Rodríguez               Orense
#
#                                                                                                                                                                                                                                                                                                           location  \
# 0                                       {'street': {'number': 7660, 'name': 'Woodland St'}, 'city': 'Newport News', 'state': 'Wyoming', 'country': 'United States', 'postcode': 31446, 'coordinates': {'latitude': '87.8260', 'longitude': '171.4450'}, 'timezone': {'offset': '-10:00', 'description': 'Hawaii'}}
# 1  {'street': {'number': 3640, 'name': 'Avenue du Château'}, 'city': 'Saint-Étienne', 'state': 'Hautes-Pyrénées', 'country': 'France', 'postcode': 61645, 'coordinates': {'latitude': '-17.1696', 'longitude': '-94.7154'}, 'timezone': {'offset': '+5:30', 'description': 'Bombay, Calcutta, Madras, New Delhi'}}
# 2  {'street': {'number': 734, 'name': 'Continuación Azerbaiyán'}, 'city': 'La Ventosa', 'state': 'Coahuila', 'country': 'Mexico', 'postcode': 60354, 'coordinates': {'latitude': '23.7690', 'longitude': '22.9621'}, 'timezone': {'offset': '+5:00', 'description': 'Ekaterinburg, Islamabad, Karachi, Tashkent'}}
# 3                           {'street': {'number': 4202, 'name': 'Rua Santa Rita '}, 'city': 'Teixeira de Freitas', 'state': 'Goiás', 'country': 'Brazil', 'postcode': 99814, 'coordinates': {'latitude': '-80.2566', 'longitude': '139.7156'}, 'timezone': {'offset': '+9:30', 'description': 'Adelaide, Darwin'}}
# 4                                    {'street': {'number': 8496, 'name': 'Calle de La Democracia'}, 'city': 'Orense', 'state': 'Navarra', 'country': 'Spain', 'postcode': 40035, 'coordinates': {'latitude': '-30.8244', 'longitude': '169.6477'}, 'timezone': {'offset': '-2:00', 'description': 'Mid-Atlantic'}}
#
#              state                            email         phn_num
# 0          Wyoming         joann.romero@example.com  (251) 323-5139
# 1  Hautes-Pyrénées      elouan.gaillard@example.com  05-28-04-77-31
# 2         Coahuila  marisela.villagomez@example.com  (633) 536 5211
# 3            Goiás       agnes.teixeira@example.com  (86) 5431-6400
# 4          Navarra     blanca.rodriguez@example.com     971-489-701

# %%
pwd
# Out:
# 'C:\\Users\\chidv\\Py_practice'
