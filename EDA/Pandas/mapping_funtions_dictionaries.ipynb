# %% [markdown]
# # Add a New & Derived Columns

# %%
import pandas as pd
import numpy as np
import random as rd
car_1df=pd.read_excel(r"C:\Users\chidv\Downloads\Data_sets\car_data.xlsx",sheet_name='car')
car_df=car_1df.copy()

# %%
car_df
# Out:
#      Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 0             1  alfa-romero       gas        std          two  convertible
# 1             2  alfa-romero       gas        std          two  convertible
# 2             3  alfa-romero       gas        std          two    hatchback
# 3             4         audi       gas        std         four        sedan
# 4             5         audi       gas        std         four        sedan
# ..          ...          ...       ...        ...          ...          ...
# 200         201        volvo       gas        std         four        sedan
# 201         202        volvo       gas      turbo         four        sedan
# 202         203        volvo       gas        std         four        sedan
# 203         204        volvo    diesel      turbo         four        sedan
# 204         205        volvo       gas      turbo         four        sedan
#
# ...

# %%
#adding the new column name 
# so use below 
car_df['manf_year']=1955 #applies the 1955 to all rows

# %%
car_df
# Out:
#      Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 0             1  alfa-romero       gas        std          two  convertible
# 1             2  alfa-romero       gas        std          two  convertible
# 2             3  alfa-romero       gas        std          two    hatchback
# 3             4         audi       gas        std         four        sedan
# 4             5         audi       gas        std         four        sedan
# ..          ...          ...       ...        ...          ...          ...
# 200         201        volvo       gas        std         four        sedan
# 201         202        volvo       gas      turbo         four        sedan
# 202         203        volvo       gas        std         four        sedan
# 203         204        volvo    diesel      turbo         four        sedan
# 204         205        volvo       gas      turbo         four        sedan
#
# ...

# %%
# tring with already exixting one s
car_df['manf_year']=1945

# %%
car_df #changeds the all values
# Out:
#      Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 0             1  alfa-romero       gas        std          two  convertible
# 1             2  alfa-romero       gas        std          two  convertible
# 2             3  alfa-romero       gas        std          two    hatchback
# 3             4         audi       gas        std         four        sedan
# 4             5         audi       gas        std         four        sedan
# ..          ...          ...       ...        ...          ...          ...
# 200         201        volvo       gas        std         four        sedan
# 201         202        volvo       gas      turbo         four        sedan
# 202         203        volvo       gas        std         four        sedan
# 203         204        volvo    diesel      turbo         four        sedan
# 204         205        volvo       gas      turbo         four        sedan
#
# ...

# %%
#changing the name of coliumn
car_df.rename(columns={'manf_year':'Year_of_Manufacture'},inplace=True)

# %%
car_df.rename(columns={'price':'price in $'},inplace=True)

# %%
car_df['Year_of_Manufacture']=np.random.randint(1945,2001,205)

# %%
# chaging the values of newly created column
car_df
# Out:
#      Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 0             1  alfa-romero       gas        std          two  convertible
# 1             2  alfa-romero       gas        std          two  convertible
# 2             3  alfa-romero       gas        std          two    hatchback
# 3             4         audi       gas        std         four        sedan
# 4             5         audi       gas        std         four        sedan
# ..          ...          ...       ...        ...          ...          ...
# 200         201        volvo       gas        std         four        sedan
# 201         202        volvo       gas      turbo         four        sedan
# 202         203        volvo       gas        std         four        sedan
# 203         204        volvo    diesel      turbo         four        sedan
# 204         205        volvo       gas      turbo         four        sedan
#
# ...

# %%
#inserting the column at choice position
car_df.insert(22,'Price in rs',0)

# %%
car_df
# Out:
#      Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 0             1  alfa-romero       gas        std          two  convertible
# 1             2  alfa-romero       gas        std          two  convertible
# 2             3  alfa-romero       gas        std          two    hatchback
# 3             4         audi       gas        std         four        sedan
# 4             5         audi       gas        std         four        sedan
# ..          ...          ...       ...        ...          ...          ...
# 200         201        volvo       gas        std         four        sedan
# 201         202        volvo       gas      turbo         four        sedan
# 202         203        volvo       gas        std         four        sedan
# 203         204        volvo    diesel      turbo         four        sedan
# 204         205        volvo       gas      turbo         four        sedan
#
# ...

# %%
# so we want convert the price in dollors to rupie
# we will have two approch

# %%
# traditional one 
lst=[]
tot=0
for every in car_df['price in $'].values:
    tot=every*87.50
    lst.append(tot)

# %%
car_df['Price in rs']=lst

# %%
car_df
# Out:
#      Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 0             1  alfa-romero       gas        std          two  convertible
# 1             2  alfa-romero       gas        std          two  convertible
# 2             3  alfa-romero       gas        std          two    hatchback
# 3             4         audi       gas        std         four        sedan
# 4             5         audi       gas        std         four        sedan
# ..          ...          ...       ...        ...          ...          ...
# 200         201        volvo       gas        std         four        sedan
# 201         202        volvo       gas      turbo         four        sedan
# 202         203        volvo       gas        std         four        sedan
# 203         204        volvo    diesel      turbo         four        sedan
# 204         205        volvo       gas      turbo         four        sedan
#
# ...

# %% [markdown]
# # Mapping using the dictionaries

# %%
# So here colm num_of_doors represents the number but in text format 
# so inorder to convert them into numarics We use dict mapping
#it is possible only for the lower type of unique values in that column
#check the unique val of that one and work wit it 
car_df.num_of_doors.unique()
# Out:
# array(['two', 'four', '?'], dtype=object)

# %%
dictdoors={'two':2,'four':4,'?':0}

# %%
car_df.num_of_doors=car_df.num_of_doors.replace(dictdoors)

# %%
car_df.num_of_doors=car_df.num_of_doors.astype(int)

# %%
car_df.num_of_doors # so all values are ints with no null or duplicate value
# Out:
# 0      2
# 1      2
# 2      2
# 3      4
# 4      4
#       ..
# 200    4
# 201    4
# 202    4
# 203    4
# 204    4
# Name: num_of_doors, Length: 205, dtype: int64

# %% [markdown]
# # Applying the funtions (Mapping using Funtions)

# %%
#or avery easy method is applying the funtions
#suppose a we want to add a catefgory to know which car is belongs to that one so we use funtions
#use apply keyword to applying the funtoon

def detect_cat(var):
    if(var<=10_000):
        return 'Affordable'
    elif(var>10_000 and var<=15_000):
        return 'Economy'
    else:
        return 'luxary'
detect_cat(1000000
# Out:
# 'luxary'

# %%
#creating the new column catogry and appling these methons
car_df['categories']=car_df['price in $'].apply(detect_cat)

# %%
car_df
# Out:
#      Unnamed: 0         make fuel_type aspiration num_of_doors   body_style  \
# 0             1  alfa-romero       gas        std          two  convertible
# 1             2  alfa-romero       gas        std          two  convertible
# 2             3  alfa-romero       gas        std          two    hatchback
# 3             4         audi       gas        std         four        sedan
# 4             5         audi       gas        std         four        sedan
# ..          ...          ...       ...        ...          ...          ...
# 200         201        volvo       gas        std         four        sedan
# 201         202        volvo       gas      turbo         four        sedan
# 202         203        volvo       gas        std         four        sedan
# 203         204        volvo    diesel      turbo         four        sedan
# 204         205        volvo       gas      turbo         four        sedan
#
# ...

# %% [markdown]
# ## using inline(Lambda Funtions)

# %%
# you want a column with the discounted price with lambda funtion 
#so discounted percentage is 10%
car_df['discounted_price$']=car_df['price in $'].apply((lambda x:x-x*(15/100)))

# %%
car_df
# Out:
#      Unnamed: 0         make fuel_type aspiration  num_of_doors   body_style  \
# 0             1  alfa-romero       gas        std             2  convertible
# 1             2  alfa-romero       gas        std             2  convertible
# 2             3  alfa-romero       gas        std             2    hatchback
# 3             4         audi       gas        std             4        sedan
# 4             5         audi       gas        std             4        sedan
# ..          ...          ...       ...        ...           ...          ...
# 200         201        volvo       gas        std             4        sedan
# 201         202        volvo       gas      turbo             4        sedan
# 202         203        volvo       gas        std             4        sedan
# 203         204        volvo    diesel      turbo             4        sedan
# 204         205        volvo       gas      turbo             4        sedan
#
# ...

# %%
(lambda x:x-x*(15/100))(100)
# Out:
# 85.0
