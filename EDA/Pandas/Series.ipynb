# %%
import pandas as pd

# %%
x=pd.Series([52,2,6,1,65,8,4])
x
# Out:
# 0    52
# 1     2
# 2     6
# 3     1
# 4    65
# 5     8
# 6     4
# dtype: int64

# %%
len(x)
# Out:
# 7

# %% [markdown]
# # Adding the series

# %%
S1=pd.Series([1,2,3,4])
S2=pd.Series([7,8])

# %%
S1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
S2
# Out:
# 0    7
# 1    8
# dtype: int64

# %%
S3=S1+S2
S3
# Out:
# 0     8.0
# 1    10.0
# 2     NaN
# 3     NaN
# dtype: float64

# %% [markdown]
# - S1+S2 #based on index it will adds the values

# %%
S3.size
# Out:
# 4

# %%
pd.DataFrame([[1,2,3,4],[5,6,7,8]])
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  5  6  7  8

# %%
pd.DataFrame([[1,2,3,4],[5,6,7,8]])
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  5  6  7  8
